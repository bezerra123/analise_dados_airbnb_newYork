# %% [markdown]
# <a href="https://colab.research.google.com/github/bezerra123/analise_dados_airbnb_newYork/blob/main/imoveis_NewYork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
 dados = pd.read_csv('train.csv')

# %%
dados
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
dados.shape
# Out:
# (48895, 16)

# %%
dados.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
dados['neighbourhood_group']
# Out:
# 0         Brooklyn
# 1        Manhattan
# 2        Manhattan
# 3         Brooklyn
# 4        Manhattan
#            ...
# 48890     Brooklyn
# 48891     Brooklyn
# 48892    Manhattan
# 48893    Manhattan
# 48894    Manhattan
# Name: neighbourhood_group, Length: 48895, dtype: object

# %%
dados[['neighbourhood_group','price']]
# Out:
#       neighbourhood_group  price
# 0                Brooklyn    149
# 1               Manhattan    225
# 2               Manhattan    150
# 3                Brooklyn     89
# 4               Manhattan     80
# ...                   ...    ...
# 48890            Brooklyn     70
# 48891            Brooklyn     40
# 48892           Manhattan    115
# 48893           Manhattan     55
# 48894           Manhattan     90
#
# [48895 rows x 2 columns]

# %%
dados['price'].mean()
# Out:
# 152.7206871868289

# %%
dados.groupby('id').mean()
# Out:
# <ipython-input-16-0a47038b9b95>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dados.groupby('id').mean()
#              host_id  latitude  longitude  price  minimum_nights  \
# id
# 2539          2787.0  40.64749  -73.97237  149.0             1.0
# 2595          2845.0  40.75362  -73.98377  225.0             1.0
# 3647          4632.0  40.80902  -73.94190  150.0             3.0
# 3831          4869.0  40.68514  -73.95976   89.0             1.0
# 5022          7192.0  40.79851  -73.94399   80.0            10.0
# ...              ...       ...        ...    ...             ...
# 36484665   8232441.0  40.67853  -73.94995   70.0             2.0
# 36485057   6570630.0  40.70184  -73.93317   40.0             4.0
# 36485431  23492952.0  40.81475  -73.94867  115.0            10.0
# ...

# %%
media_valor_bairro = dados.groupby('neighbourhood').mean('price')
# Out:
#                            id       host_id   latitude  longitude       price  \
# neighbourhood
# Allerton         2.007729e+07  1.052045e+08  40.865292 -73.858727   87.595238
# Arden Heights    2.935619e+07  1.695545e+08  40.552410 -74.182253   67.250000
# Arrochar         2.077441e+07  8.173055e+07  40.593900 -74.074600  115.000000
# Arverne          2.129500e+07  8.311746e+07  40.591853 -73.794839  171.779221
# Astoria          1.895895e+07  6.845130e+07  40.764299 -73.920002  117.187778
# ...                       ...           ...        ...        ...         ...
# Windsor Terrace  1.561427e+07  4.072202e+07  40.654612 -73.977990  138.993631
# Woodhaven        2.565286e+07  1.041632e+08  40.691968 -73.858232   67.170455
# Woodlawn         2.189746e+07  8.643503e+07  40.897421 -73.867939   60.090909
# Woodrow          1.798271e+06  9.430973e+06  40.538840 -74.198260  700.000000
# Woodside         2.412387e+07  1.067271e+08  40.745925 -73.902723   85.097872
#
# ...

# %%
dados.groupby('neighbourhood')[['price']].mean().sort_values('price')
# Out:
#                      price
# neighbourhood
# Bull's Head      47.333333
# Hunts Point      50.500000
# Tremont          51.545455
# Soundview        53.466667
# New Dorp         57.000000
# ...                    ...
# Riverdale       442.090909
# Sea Gate        487.857143
# Tribeca         490.638418
# Woodrow         700.000000
# Fort Wadsworth  800.000000
#
# [221 rows x 1 columns]

# %%
dados.neighbourhood.value_counts(normalize=True) * 100
# Out:
# Williamsburg          8.017180
# Bedford-Stuyvesant    7.595869
# Harlem                5.436139
# Bushwick              5.041415
# Upper West Side       4.031087
#                         ...
# Fort Wadsworth        0.002045
# Richmondtown          0.002045
# New Dorp              0.002045
# Rossville             0.002045
# Willowbrook           0.002045
# Name: neighbourhood, Length: 221, dtype: float64

# %%
maior_media_bairro = dados.groupby('neighbourhood')['price'].mean().sort_values().nlargest(5)
maior_media_bairro
# Out:
# neighbourhood
# Fort Wadsworth    800.000000
# Woodrow           700.000000
# Tribeca           490.638418
# Sea Gate          487.857143
# Riverdale         442.090909
# Name: price, dtype: float64

# %%
maior_valor_bairro = dados.groupby('neighbourhood')['price'].max().sort_values().nlargest(5)
maior_valor_bairro
# Out:
# neighbourhood
# Greenpoint         10000
# Astoria            10000
# Upper West Side    10000
# East Harlem         9999
# Lower East Side     9999
# Name: price, dtype: int64

# %%
menor_valor_bairro = dados.groupby('neighbourhood')['price'].min().sort_values().nlargest(5)
menor_valor_bairro
# Out:
# neighbourhood
# Fort Wadsworth    800
# Woodrow           700
# Willowbrook       249
# Neponsit          200
# Breezy Point      195
# Name: price, dtype: int64

# %%
maior_media_bairro.plot(kind='bar', figsize=(14,10), color = 'red', ylabel='Porcentual Medias' )
# Out:
# <Axes: xlabel='neighbourhood', ylabel='Porcentual Medias'>

# %%
menor_valor_bairro.plot(kind='bar', figsize=(14,10), color = 'black', ylabel='menores medias'  )
# Out:
# <Axes: xlabel='neighbourhood', ylabel='menores medias'>

# %%
dados.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
dados.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
dados = dados.fillna(0)

# %%
dados.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
valores_removerem = dados.query('price == 0').index

# %%
dados.drop(valores_removerem, axis=0, inplace=True)

# %%
dados.query('price == 0').index
# Out:
# Int64Index([], dtype='int64')

# %%
selecao = (dados['price'] > 999) & (dados['number_of_reviews'] > 10)
dados[selecao]
# Out:
#              id                                               name    host_id  \
# 496      174966              Luxury 2Bed/2.5Bath Central Park View     836168
# 762      273190          6 Bedroom Landmark West Village Townhouse     605463
# 1414     634353                Luxury 1Bed with Central Park Views     836168
# 1480     664047                Lux 2Bed/2.5Bath Central Park Views     836168
# 2018     893413         Architecturally Stunning Former Synagogue!    4751930
# 2215    1039983                   Tribeca Loft w/ Private Elevator     273174
# 2236    1056256  Beautiful eco triplex w/green roof. Free yoga/...     462379
# 2355    1146653                Luxury 1 Bedroom Central Park Views     836168
# 2523    1301321                West Village Penthouse-terrace/view    2214774
# 2772    1515692                Beautiful Lower East Side Penthouse    4358024
# 3306    1976123                    Huge Loft with Private Entrance    6547579
# ...

# %%
dados.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
media_tipo_quarto = dados.groupby('room_type')[['price']].mean()

# %%
media_tipo_quarto.plot(kind='bar', figsize=(10,10), ylabel='media de valores')
# Out:
# <Axes: xlabel='room_type', ylabel='media de valores'>

# %%
dados.host_id.value_counts().nlargest(10)
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 12243051      96
# 16098958      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: host_id, dtype: int64

# %%
dados.query('host_id == 219517861')
# Out:
#              id                                               name    host_id  \
# 38293  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708        Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590            Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591        Sonder | The Nash | Lovely Studio + Rooftop  219517861
# ...         ...                                                ...        ...
# 47691  35871510  Sonder | 116 John | Vibrant Studio + Fitness Room  219517861
# 47692  35871511     Sonder | 116 John | Vibrant 1BR + Fitness Room  219517861
# 47693  35871515         Sonder | 116 John | Stunning 1BR + Rooftop  219517861
# 47814  35936418          Sonder | 116 John | Polished Studio + Gym  219517861
# 47821  35937891            Sonder | 116 John | Simple Studio + Gym  219517861
#
# ...

# %%
dono_imorvel_ordenado = dono_de_mais_imoveis.sort_values(by='price', ascending=False )

# %%
dono_imorvel_ordenado
# Out:
#              id                                          name    host_id  \
# 47821  35937891       Sonder | 116 John | Simple Studio + Gym  219517861
# 44326  34177117                   Sonder | The Biltmore | 1BR  219517861
# 47814  35936418     Sonder | 116 John | Polished Studio + Gym  219517861
# 44590  34313960               Lovely Studio in FiDi by Sonder  219517861
# 44587  34313143                Superior 1BR in FiDi by Sonder  219517861
# ...         ...                                           ...        ...
# 44179  34087749    Sonder | 116 John | Laid-Back Studio + Gym  219517861
# 45932  35005134        Sonder | 116 John | Sleek Studio + Gym  219517861
# 44554  34291583      Sonder | 116 John | Relaxed Studio + Gym  219517861
# 44534  34284409       Sonder | 116 John | Modern Studio + Gym  219517861
# 45934  35005183  Sonder | 116 John | Comfortable Studio + Gym  219517861
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
# Supondo que 'dados' seja o seu DataFrame e 'price' seja a coluna de interesse
indice_maior_preco =dados['price'].idxmax()
linha_maior = dados.loc[indice_maior_valor]
linha_maior
# Out:
# id                                                            7003697
# name                              Furnished room in Astoria apartment
# host_id                                                      20582832
# host_name                                                    Kathrine
# neighbourhood_group                                            Queens
# neighbourhood                                                 Astoria
# latitude                                                      40.7681
# longitude                                                   -73.91651
# room_type                                                Private room
# price                                                           10000
# minimum_nights                                                    100
# number_of_reviews                                                   2
# last_review                                                2016-02-13
# ...

# %%
maior_valor = dados.query('price == price.max()')
maior_valor
# Out:
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0           0
#
# ...
